# %% [markdown]
# # LABS-3: Systems Project
#
# In this notebook you will run a few cells to ensure that your environment is properly set up.

# %%
## First cell
# run this for step 11 in your instructions

print("Hello, World!")
# Out:
# Hello, World!

# %%
## Second cell
# run this for step 14 in your instructions

import pandas as pd

# %%
## Part 3: Accessing your data
# edit this code to load your data into your workspace
import pandas as pd
data1 = pd.read_csv("imdb_movies.csv")
data1.head
# Out:
# <bound method NDFrame.head of                                          names       date_x  score  \
# 0                                    Creed III  03/02/2023    73.0
# 1                     Avatar: The Way of Water  12/15/2022    78.0
# 2                  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                                      Mummies  01/05/2023    70.0
# 4                                    Supercell  03/17/2023    61.0
# ...                                        ...          ...    ...
# 10173                       20th Century Women  12/28/2016    73.0
# 10174  Delta Force 2: The Colombian Connection  08/24/1990    54.0
# 10175                         The Russia House  12/21/1990    61.0
# 10176         Darkman II: The Return of Durant  07/11/1995    55.0
# 10177       The Swan Princess: A Royal Wedding  07/20/2020    70.0
#
#                                                    genre  \
# 0                                          Drama, Action
# ...
